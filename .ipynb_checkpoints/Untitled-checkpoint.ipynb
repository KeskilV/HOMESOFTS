# %%
import numpy as np
import pandas as pd
import datetime
bros = ['kes','sar','nur']
oyuns = pd.DataFrame(columns = ['дата','наименование','платил','сумма'])

pd.set_option('display.float_format', '{:.2f}'.format)

def status():
    print('  на  ',oyuns.loc[len(oyuns)-1, 'дата'],"\n",oyuns ,"\n")
    sumpay = oyuns[['платил','сумма']].groupby(by = 'платил').sum()
    print('общая сумма: {:.2f} '.format(float(sumpay.sum())))
    print('\n', sumpay)
    eqsum = round(sumpay.sum()/len(bros),2)
    print('\n\nвсе должны были скинуться: {:.2f}'.format (float(eqsum)))
    offsetval = eqsum -sumpay
    offsetval.columns= ["суммы для взаимозачета"]
    print(offsetval,'\n\n') #Это на сколько должен 
def offset(date):
	#успешный взаимозачет
	global oyuns
	sumpay = oyuns[['платил','сумма']].groupby(by = 'платил').sum()
	eqsum = round(sumpay.sum()/len(bros),2)
	
	offsetval = eqsum -sumpay
	offsetval['платил'] = offsetval.index
	offsetval['наименование'] ="взаимозачет"
	offsetval['дата'] = date
	oyuns = pd.concat([oyuns,offsetval], ignore_index = True)
	
	
#затраты на 15.07.2021
datez = datetime.date(2021,7,15)
oyuns.loc[0] = [datez,'за батарею сварщику',bros[0],5000.0]
oyuns.loc[1] = [datez,'за краны',bros[0],700.0]
oyuns.loc[2] = [datez,'за окна',bros[2],32300.0]
oyuns.loc[3] = [datez,'',bros[1],0]

status()
#взамочачет прошел
offset(datetime.date(2021,7,17))

status()

#затраты на 15.08.21
#datez = datetime.date(2021,7,xx)
#datez = datetime.date.today()
oyuns.loc[len(oyuns)] = [datetime.date(2021,7,21),'удалитель краски', bros[2],629]
oyuns.loc[len(oyuns)] = [datetime.date(2021,7,24),'шпатлевка по дереву', bros[2],75.65]
oyuns.loc[len(oyuns)] = [datetime.date(2021,7,24),'грунтовка 2 по 5л', bros[2],730]
oyuns.loc[len(oyuns)] = [datetime.date(2021,7,25),'линолеум', bros[2],3742.55]
oyuns.loc[len(oyuns)] = [datetime.date(2021,7,25),'самовыравн смесь 4 мешка', bros[2],2996]
oyuns.loc[len(oyuns)] = [datetime.date(2021,7,25),'плинтуса', bros[2],436.90]
oyuns.loc[len(oyuns)] = [datetime.date(2021,7,25),'игольчатый', bros[2],344.25]
oyuns.loc[len(oyuns)] = [datetime.date(2021,7,25),'пена', bros[2],211.65]
oyuns.loc[len(oyuns)] = [datetime.date(2021,7,24),'юбка', bros[2],70]
offset(datetime.date(2021,7,29))
oyuns.loc[len(oyuns)] = [datetime.date(2021,7,30),'обои+всякое', bros[0],6733]
oyuns.loc[len(oyuns)] = [datetime.date(2021,7,31),'шпаклевка', bros[2],576]
oyuns.loc[len(oyuns)] = [datetime.date(2021,7,31),'угол', bros[2],140]
import numpy as np
import pandas as pd
import datetime
bros = ['kes','sar','nur']
oyuns = pd.DataFrame(columns = ['дата','наименование','платил','сумма'])

pd.set_option('display.float_format', '{:.2f}'.format)

def status():
    print('  на  ',oyuns.loc[len(oyuns)-1, 'дата'],"\n",oyuns ,"\n")
    sumpay = oyuns[['платил','сумма']].groupby(by = 'платил').sum()
    print('общая сумма: {:.2f} '.format(float(sumpay.sum())))
    print('\n', sumpay)
    eqsum = round(sumpay.sum()/len(bros),2)
    print('\n\nвсе должны были скинуться: {:.2f}'.format (float(eqsum)))
    offsetval = eqsum -sumpay
    offsetval.columns= ["суммы для взаимозачета"]
    print(offsetval,'\n\n') #Это на сколько должен 
def offset(date):
	#успешный взаимозачет
	global oyuns
	sumpay = oyuns[['платил','сумма']].groupby(by = 'платил').sum()
	eqsum = round(sumpay.sum()/len(bros),2)
	
	offsetval = eqsum -sumpay
	offsetval['платил'] = offsetval.index
	offsetval['наименование'] ="взаимозачет"
	offsetval['дата'] = date
	oyuns = pd.concat([oyuns,offsetval], ignore_index = True)
	
	
#затраты на 15.07.2021
datez = datetime.date(2021,7,15)
oyuns.loc[0] = [datez,'за батарею сварщику',bros[0],5000.0]
oyuns.loc[1] = [datez,'за краны',bros[0],700.0]
oyuns.loc[2] = [datez,'за окна',bros[2],32300.0]
oyuns.loc[3] = [datez,'',bros[1],0]

status()
#взамочачет прошел
offset(datetime.date(2021,7,17))

status()

#затраты на 15.08.21
#datez = datetime.date(2021,7,xx)
#datez = datetime.date.today()
oyuns.loc[len(oyuns)] = [datetime.date(2021,7,21),'удалитель краски', bros[2],629]
oyuns.loc[len(oyuns)] = [datetime.date(2021,7,24),'шпатлевка по дереву', bros[2],75.65]
oyuns.loc[len(oyuns)] = [datetime.date(2021,7,24),'грунтовка 2 по 5л', bros[2],730]
oyuns.loc[len(oyuns)] = [datetime.date(2021,7,25),'линолеум', bros[2],3742.55]
oyuns.loc[len(oyuns)] = [datetime.date(2021,7,25),'самовыравн смесь 4 мешка', bros[2],2996]
oyuns.loc[len(oyuns)] = [datetime.date(2021,7,25),'плинтуса', bros[2],436.90]
oyuns.loc[len(oyuns)] = [datetime.date(2021,7,25),'игольчатый', bros[2],344.25]
oyuns.loc[len(oyuns)] = [datetime.date(2021,7,25),'пена', bros[2],211.65]
oyuns.loc[len(oyuns)] = [datetime.date(2021,7,24),'юбка', bros[2],70]
offset(datetime.date(2021,7,29))
oyuns.loc[len(oyuns)] = [datetime.date(2021,7,30),'обои+всякое', bros[0],6733]
oyuns.loc[len(oyuns)] = [datetime.date(2021,7,31),'шпаклевка', bros[2],576]
oyuns.loc[len(oyuns)] = [datetime.date(2021,7,31),'угол', bros[2],140]
#15-08-2021
oyuns.loc[len(oyuns)] = [datetime.date(2021,8,10),'розетка бур дюбели', bros[0],781]
oyuns.loc[len(oyuns)] = [datetime.date(2021,8,10),'резак', bros[1],212]
oyuns.loc[len(oyuns)] = [datetime.date(2021,8,11),'кухня', bros[0],20000]
oyuns.loc[len(oyuns)] = [datetime.date(2021,8,10),'линолеум эмаль', bros[0],7907]



status()
#шаблон для затрат
#затраты на   .07.2021
#datez = datetime.date(2021,7,xx)
#datez = datetime.date.today()
#oyuns.loc[len(oyuns)] = [datez,'bla', bros[0],0]
#status()


#стираем последний
#oyuns.drop(len(oyuns)-1, inplace = True)

#запись файла в ехсел
oyuns.to_excel('ouyns.xlsx')


status()
#шаблон для затрат
#затраты на   .07.2021
#datez = datetime.date(2021,7,xx)
#datez = datetime.date.today()
#oyuns.loc[len(oyuns)] = [datez,'bla', bros[0],0]
#status()


#стираем последний
#oyuns.drop(len(oyuns)-1, inplace = True)

#запись файла в ехсел
oyuns.to_excel('ouyns.xlsx')
# Out:
#   на   2021-07-15
#           дата         наименование платил    сумма
# 0  2021-07-15  за батарею сварщику    kes  5000.00
# 1  2021-07-15             за краны    kes   700.00
# 2  2021-07-15              за окна    nur 32300.00
# 3  2021-07-15                         sar     0.00
#
# общая сумма: 38000.00
#
#            сумма
# платил
# kes     5700.00
# nur    32300.00
# sar        0.00
#
#
# все должны были скинуться: 12666.67
#         суммы для взаимозачета
# платил
# kes                    6966.67
# nur                  -19633.33
# sar                   12666.67
#
#
#   на   2021-07-17
#           дата         наименование платил     сумма
# 0  2021-07-15  за батарею сварщику    kes   5000.00
# 1  2021-07-15             за краны    kes    700.00
# 2  2021-07-15              за окна    nur  32300.00
# 3  2021-07-15                         sar      0.00
# 4  2021-07-17          взаимозачет    kes   6966.67
# 5  2021-07-17          взаимозачет    nur -19633.33
# ...
